# %%
import numpy as np
from matplotlib import pyplot as plt
from pylab import genfromtxt

# %%
data = genfromtxt("build/output_result.txt")

fig= plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')

plt.title("EKF-Radar Reverse")

plt.plot(data[:,4], data[:,5], label = "Laser measurementes ");
plt.plot(data[:,6], data[:,7], label = "Ground Truth");
plt.plot(data[:,0], data[:,1], label = "Estimated");
plt.legend();
fig.savefig('./out_Images/EKF-R_Reverse.png')
plt.show();
